# %% [markdown]
# # A comparison of density profiles from similar chain length distributions

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import custom package
import brush as b
from config import FIGURE_SIZE_LARGE, FIGURE_DPI, nature_colors, FIGURE_SIZE

# %% [markdown]
# ## Load the profiles from data

# %%
# Load the profiles
osmotic_prefactor = 1.0
volume_scaling = 1.667
brush_10 = b.Brush("simulation",
                   {"filename": "../data/Density_Profile_D100.csv"},
                   osmotic_prefactor=osmotic_prefactor)
brush_11 = b.Brush("simulation",
                   {"filename": "../data/Density_Profile_D110.csv"},
                   osmotic_prefactor=osmotic_prefactor)
brush_12 = b.Brush("simulation",
                   {"filename": "../data/Density_Profile_D120.csv"},
                   osmotic_prefactor=osmotic_prefactor)
brush_14 = b.Brush("simulation",
                   {"filename": "../data/Density_profile_D140.csv"},
                   osmotic_prefactor=osmotic_prefactor)
brush_10_th = b.Brush("model",
                      {"type" : "gaussian",
                       "Mn" : 100,
                       "sigma" : 0.1},
                       volume_scaling=volume_scaling)
brush_11_th = b.Brush("model",
                      {"type": "schulz-zimm",
                       "Mn" : 100,
                       "D" : 1.1},
                       volume_scaling=volume_scaling)
brush_12_th = b.Brush("model",
                      {"type": "schulz-zimm",
                       "Mn" : 100,
                       "D" : 1.2},
                       volume_scaling=volume_scaling)
brush_14_th = b.Brush("model",
                      {"type": "schulz-zimm",
                       "Mn" : 100,
                       "D" : 1.4},
                       volume_scaling=volume_scaling)

# %% [markdown]
# ## Plot comparison

# %%
fig, ax = plt.subplots(figsize=(FIGURE_SIZE[0],FIGURE_SIZE[1]*2.5), dpi=FIGURE_DPI,ncols=1,nrows=4)

ax[0].plot(brush_10.z, brush_10.phi_N, "-", label='Simulation', color=nature_colors[3])
ax[0].fill_between(brush_10.z, brush_10.ci_lower, brush_10.ci_upper, alpha=0.3, color=nature_colors[3], edgecolor=None)
ax[0].plot(brush_10_th.z,brush_10_th.phi_N,'--', label='Theory', color=nature_colors[3])
ax[0].set_title("D = 1.0")

ax[1].plot(brush_11.z, brush_11.phi_N, "-", label='Simulation', color=nature_colors[0])
ax[1].fill_between(brush_11.z, brush_11.ci_lower, brush_11.ci_upper, alpha=0.3, color=nature_colors[0], edgecolor=None)
ax[1].plot(brush_11_th.z,brush_11_th.phi_N,'--', label='Theory', color=nature_colors[0])
ax[1].set_title("D = 1.1")


ax[2].plot(brush_12.z, brush_12.phi_N, "-", label='Simulation', color=nature_colors[1])
ax[2].fill_between(brush_12.z, brush_12.ci_lower, brush_12.ci_upper, alpha=0.3, color=nature_colors[1], edgecolor=None)
ax[2].plot(brush_12_th.z,brush_12_th.phi_N,'--', label='Theory', color=nature_colors[1])
ax[2].set_title("D = 1.2")


ax[3].plot(brush_14.z, brush_14.phi_N, "-", label='Simulation', color=nature_colors[2])
ax[3].fill_between(brush_14.z, brush_14.ci_lower, brush_14.ci_upper, alpha=0.3, color=nature_colors[2], edgecolor=None)
ax[3].plot(brush_14_th.z,brush_14_th.phi_N,'--', label='Theory', color=nature_colors[2])
ax[3].set_title("D = 1.4")


for i, ax in enumerate(fig.axes):
    ax.set_ylabel(str(i))
    ax.set_xlim([0,100])
    if i == 3:
        ax.set_xlabel("Distance [$\sigma$]")
    ax.set_ylim([0,0.5])
    ax.set_ylabel("Number density [$\sigma^{-3}$]")
    ax.legend()
    
# fig.suptitle("Comparing simulation and theoretical profiles")
fig.tight_layout()
fig.savefig("../results/figures/density_profiles-onecol.png")
